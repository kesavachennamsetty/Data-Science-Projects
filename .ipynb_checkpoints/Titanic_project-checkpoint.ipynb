# %%
import pandas as pd
import numpy as np

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 7210-D35D
#
#  Directory of C:\Users\ramac\Projects\Data-Science-Projects
#
# 09/14/2024  04:43 PM    <DIR>          .
# 09/14/2024  04:43 PM    <DIR>          ..
# 09/14/2024  04:33 PM    <DIR>          .ipynb_checkpoints
# 09/09/2024  12:41 PM        46,075,597 AcademicHistory25.csv
# 09/09/2024  12:08 PM        81,993,874 Data.csv
# 09/13/2024  01:23 PM             3,258 gender_submission.csv
# 09/13/2024  04:25 PM           109,621 Grade_Prediction_Project_12.ipynb
# 09/13/2024  01:24 PM            28,629 test.csv
# 09/14/2024  04:43 PM            65,027 Titanic_project.ipynb
# 09/13/2024  01:24 PM            61,194 train.csv
# 09/13/2024  10:11 AM             7,862 Untitled.ipynb
# 09/13/2024  09:50 AM           635,333 Urban_Air_Quality_and_Health_Impact_Dataset.csv
#                9 File(s)    128,980,395 bytes
#                3 Dir(s)  142,513,885,184 bytes free

# %%
df_train = pd.read_csv('train.csv')

# %%
df_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df_train = df_train[['Survived', 'Pclass', 'Sex', 'Age', 'SibSp','Parch','Fare', 'Embarked']]

# %%
df_train
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female   NaN      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
df_train['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df_train['Sex_int'] = df_train['Sex'].replace({'male':1,'female':0})
# Out:
# C:\Users\ramac\AppData\Local\Temp\ipykernel_8004\4164722013.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_train['Sex_int'] = df_train['Sex'].replace({'male':1,'female':0})

# %%
df_train['Embarked_int'] = df_train['Embarked'].replace({'S':1,'C':2,'Q':3})
# Out:
# C:\Users\ramac\AppData\Local\Temp\ipykernel_8004\3762101794.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_train['Embarked_int'] = df_train['Embarked'].replace({'S':1,'C':2,'Q':3})

# %%
df_train.isna().sum()
# Out:
# Survived          0
# Pclass            0
# Sex               0
# Age             177
# SibSp             0
# Parch             0
# Fare              0
# Embarked          2
# Sex_int           0
# Embarked_int      2
# dtype: int64

# %%
df_train = df_train.fillna(0)

# %%
df_train_features = df_train[['Pclass','Age','SibSp','Parch','Fare','Embarked_int','Sex_int']]
df_train_target = df_train['Survived']

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
param_grid = { 
    'n_estimators': [25, 50, 100, 150], 
    'max_depth': [3, 6, 9], 
    'max_leaf_nodes': [1,2,3, 6, 9],
    'min_samples_leaf':[0,1,2,3,5,4]
}

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ## Finding Best Hyperparameters in RandomForest Model

# %%
grid_search = GridSearchCV(RandomForestClassifier(), 
                           param_grid=param_grid) 
grid_search.fit(df_train_features, df_train_target) 
print(grid_search.best_estimator_)
# Out:
# C:\Users\ramac\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 600 fits failed out of a total of 1800.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 360 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\ramac\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ramac\anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Users\ramac\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\ramac\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_leaf_nodes' parameter of RandomForestClassifier must be an int in the range [2, inf) or None. Got 1 instead.
#
# --------------------------------------------------------------------------------
# 240 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\ramac\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ramac\anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Users\ramac\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\ramac\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_samples_leaf' parameter of RandomForestClassifier must be an int in the range [1, inf) or a float in the range (0.0, 1.0). Got 0 instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\ramac\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan 0.75537631 0.74188689
#  0.77562614 0.75986442 0.77331618 0.77781684 0.76772331 0.78008913
#  0.74861591 0.75761722 0.75985814 0.77671835 0.75872827 0.76214927
#  0.77784194 0.77111292 0.75876593 0.75987697 0.75762978 0.77895926
#         nan        nan        nan        nan 0.78904651 0.77897182
#  0.78904651 0.78342226 0.77332245 0.77783567 0.77894043 0.78231122
#  0.80470153 0.78343481 0.78342854 0.78457096 0.77332245 0.78793547
#  0.79242358 0.78567573 0.785682   0.79128743 0.79017639 0.77896554
#         nan        nan        nan        nan 0.78574477 0.793566
#  0.79020149 0.79021405 0.77450254 0.78797313 0.798029   0.79580692
#  0.80472663 0.80249827 0.80143117 0.78683071 0.80247944 0.80584395
#  0.78683698 0.79242358 0.77675601 0.78572594 0.79243613 0.79133137
#         nan        nan        nan        nan 0.79800389 0.78908418
#  0.81033833 0.7935409  0.79691796 0.79470215 0.77897809 0.79692424
#  0.80361559 0.79355973 0.80141234 0.79470215 0.77450882 0.79131254
#  0.79804155 0.80028875 0.79807294 0.78793547 0.78685582 0.80364698
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan 0.76546356 0.73408449
#  0.76100056 0.76659971 0.76658088 0.76545101 0.77669324 0.77223652
#  0.77671835 0.75761722 0.77108782 0.77110665 0.7733915  0.75534492
#  0.75874082 0.7767309  0.74076329 0.76437135 0.76325403 0.77332873
#         nan        nan        nan        nan 0.77448999 0.77673718
#  0.7868056  0.77781056 0.78118134 0.7811939  0.78566945 0.77894671
#  0.75658778 0.78679305 0.78679932 0.78455213 0.78123784 0.77896554
#  0.78230494 0.78679932 0.78796686 0.77783567 0.78455213 0.78679932
#         nan        nan        nan        nan 0.79131254 0.79465821
#  0.80141862 0.79471471 0.78572594 0.79693051 0.79693051 0.79915887
#  0.78905907 0.80253594 0.80699266 0.79582575 0.79693051 0.79244241
#  0.78237399 0.79357856 0.8036407  0.78122528 0.79580064 0.79467704
#         nan        nan        nan        nan 0.8125918  0.80696127
#  0.798029   0.80029502 0.81370912 0.80584395 0.79023916 0.80251711
#  0.81148704 0.78909045 0.81483899 0.80586906 0.80471408 0.80701149
#  0.80475174 0.80924612 0.78797313 0.79134392 0.80474546 0.79246752
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan 0.74977716 0.76660599
#  0.7632352  0.77782311 0.73975268 0.7744586  0.75426527 0.77448371
#  0.76885946 0.77108782 0.76999561 0.7767309  0.72959638 0.78342854
#  0.77447116 0.76886573 0.7351767  0.76659971 0.76999561 0.7744586
#         nan        nan        nan        nan 0.78005147 0.78342854
#  0.78679305 0.78567573 0.78681188 0.78566945 0.78343481 0.7912937
#  0.77332245 0.77443977 0.77557592 0.78567573 0.79128743 0.79130626
#  0.78678677 0.78230494 0.78793547 0.78005775 0.78455213 0.78342854
#         nan        nan        nan        nan 0.80807859 0.79246124
#  0.798029   0.80140606 0.79242358 0.80696127 0.7946896  0.79472726
#  0.81369029 0.78799197 0.79357228 0.79247379 0.78124412 0.78797941
#  0.79467077 0.79355345 0.78125039 0.79359739 0.79355345 0.8003013
#         nan        nan        nan        nan 0.81148076 0.80138096
#  0.7991777  0.79920281 0.81033833 0.80027619 0.80473291 0.79693051
#  0.81370912 0.80143117 0.80028247 0.80254221 0.80138723 0.79917143
#  0.80477685 0.80367836 0.7991526  0.7958383  0.8047643  0.80254221]
#   warnings.warn(
# RandomForestClassifier(max_depth=6, max_leaf_nodes=9, min_samples_leaf=3)

# %%
clf = RandomForestClassifier(random_state = 42,max_depth=6, max_leaf_nodes=9, min_samples_leaf=3,n_estimators=150)

# %%
df_train_features = df_train[['Pclass', 'Sex_int', 'Age', 'SibSp','Parch','Fare', 'Embarked_int']]

# %%
df_train_target = df_train['Survived']

# %%
clf.fit(df_train_features, df_train_target)
# Out:
# RandomForestClassifier(max_depth=6, max_leaf_nodes=9, min_samples_leaf=3,
#                        n_estimators=150, random_state=42)

# %%
df_test = pd.read_csv('test.csv')

# %%
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df_test['Sex_int'] = df_test['Sex'].replace({'male':1,'female':0})
# Out:
# C:\Users\ramac\AppData\Local\Temp\ipykernel_8004\3228916345.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_test['Sex_int'] = df_test['Sex'].replace({'male':1,'female':0})

# %%
df_test['Embarked_int'] = df_test['Embarked'].replace({'S':1,'C':2,'Q':3})
# Out:
# C:\Users\ramac\AppData\Local\Temp\ipykernel_8004\3703366418.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_test['Embarked_int'] = df_test['Embarked'].replace({'S':1,'C':2,'Q':3})

# %%
df_test = df_test[['PassengerId', 'Pclass','Sex_int','Embarked_int','Fare','Age','SibSp','Parch']]

# %%
d_gender_submission = pd.read_csv('gender_submission.csv')

# %%
d_test_gender_submission = pd.merge(df_test,d_gender_submission, on = 'PassengerId',how= 'left')

# %%
d_test_gender_submission.shape
# Out:
# (418, 9)

# %%
d_test_gender_submission['predict'] = clf.predict(d_test_gender_submission[['Pclass','Sex_int','Age','SibSp','Parch','Fare','Embarked_int']])

# %%
d_test_gender_submission[['predict','Survived']]
# Out:
#      predict  Survived
# 0          0         0
# 1          0         1
# 2          0         0
# 3          0         0
# 4          0         1
# ..       ...       ...
# 413        0         0
# 414        1         1
# 415        0         0
# 416        0         0
# 417        0         0
#
# [418 rows x 2 columns]

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(d_test_gender_submission['Survived'],d_test_gender_submission['predict'])
# Out:
# 0.8851674641148325

# %% [markdown]
# ## LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression

# %%
d_test_gender_submission =d_test_gender_submission.fillna(0)

# %%
logr = LogisticRegression(C=1.2, solver='liblinear')

# %%
logr.fit(df_train_features, df_train_target)
# Out:
# LogisticRegression(C=1.2, solver='liblinear')

# %%
accuracy_score(d_test_gender_submission['Survived'],logr.predict(d_test_gender_submission[['Pclass','Sex_int','Age','SibSp','Parch','Fare','Embarked_int']]))
# Out:
# 0.9712918660287081

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import accuracy_score

# %%
Decisiontree_classifier = DecisionTreeClassifier()

# %%
Decisiontree_classifier.fit(df_train_features, df_train_target)
# Out:
# DecisionTreeClassifier()

# %%
accuracy_score(d_test_gender_submission['Survived'],Decisiontree_classifier.predict(d_test_gender_submission[['Pclass','Sex_int','Age','SibSp','Parch','Fare','Embarked_int']]))
# Out:
# 0.7703349282296651

# %%
param_grid_dt = { 
    'max_depth': [3, 6, 9], 
    'max_leaf_nodes': [1,2,3, 6, 9],
    'min_samples_leaf':[0,1,2,3,5,4]
}

# %%
grid_search = GridSearchCV(estimator = Decisiontree_classifier, 
                           param_grid=param_grid_dt) 
grid_search.fit(df_train_features, df_train_target) 
print(grid_search.best_estimator_)
# Out:
# DecisionTreeClassifier(max_depth=6, max_leaf_nodes=9, min_samples_leaf=5)
# C:\Users\ramac\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 150 fits failed out of a total of 450.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 90 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\ramac\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ramac\anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Users\ramac\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\ramac\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_leaf_nodes' parameter of DecisionTreeClassifier must be an int in the range [2, inf) or None. Got 1 instead.
#
# --------------------------------------------------------------------------------
# 60 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\ramac\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ramac\anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Users\ramac\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\ramac\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_samples_leaf' parameter of DecisionTreeClassifier must be an int in the range [1, inf) or a float in the range (0.0, 1.0). Got 0 instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\ramac\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan 0.78673655 0.78673655 0.78673655 0.78673655 0.78673655
#         nan 0.77331618 0.77331618 0.77331618 0.77331618 0.77331618
#         nan 0.80582512 0.80582512 0.80582512 0.80582512 0.80582512
#         nan 0.80582512 0.80582512 0.80582512 0.80582512 0.80582512
#         nan        nan        nan        nan        nan        nan
#         nan 0.78673655 0.78673655 0.78673655 0.78673655 0.78673655
#         nan 0.77331618 0.77331618 0.77331618 0.77331618 0.77331618
#         nan 0.80470153 0.80470153 0.80470153 0.80470153 0.80470153
#         nan 0.80693616 0.80693616 0.80693616 0.80805976 0.80805976
#         nan        nan        nan        nan        nan        nan
#         nan 0.78673655 0.78673655 0.78673655 0.78673655 0.78673655
#         nan 0.77331618 0.77331618 0.77331618 0.77331618 0.77331618
#         nan 0.80470153 0.80470153 0.80470153 0.80470153 0.80470153
#         nan 0.80693616 0.80693616 0.80693616 0.80805976 0.80805976]
#   warnings.warn(

# %%
Decision_tree_clf_hypr_tung = DecisionTreeClassifier(max_depth=6, max_leaf_nodes=9, min_samples_leaf=5)

# %%
Decision_tree_clf_hypr_tung.fit(df_train_features, df_train_target)
# Out:
# DecisionTreeClassifier(max_depth=6, max_leaf_nodes=9, min_samples_leaf=5)

# %%
accuracy_score(d_test_gender_submission['Survived'],Decision_tree_clf_hypr_tung.predict(d_test_gender_submission[['Pclass','Sex_int','Age','SibSp','Parch','Fare','Embarked_int']]))
# Out:
# 0.861244019138756
