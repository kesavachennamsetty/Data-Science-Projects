# %%
import pandas as pd
import numpy as np

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is CC57-E755
#
#  Directory of C:\Users\Admin\Downloads\titanic (1)
#
# 09/05/2024  02:15 PM    <DIR>          .
# 09/05/2024  02:15 PM    <DIR>          ..
# 09/05/2024  01:54 PM    <DIR>          .ipynb_checkpoints
# 09/05/2024  01:13 PM             3,258 gender_submission.csv
# 09/05/2024  01:13 PM            28,629 test.csv
# 09/05/2024  02:15 PM            44,841 titanic_proect.ipynb
# 09/05/2024  01:13 PM            61,194 train.csv
#                4 File(s)        137,922 bytes
#                3 Dir(s)  768,702,910,464 bytes free

# %%
df_train = pd.read_csv('train.csv')

# %%
df_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df_train = df_train[['Survived', 'Pclass', 'Sex', 'Age', 'SibSp','Parch','Fare', 'Embarked']]

# %%
df_train
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female   NaN      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
df_train['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df_train['Sex_int'] = df_train['Sex'].replace({'male':1,'female':0})
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4468\4164722013.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_train['Sex_int'] = df_train['Sex'].replace({'male':1,'female':0})

# %%
df_train['Embarked_int'] = df_train['Embarked'].replace({'S':1,'C':2,'Q':3})
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4468\3762101794.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_train['Embarked_int'] = df_train['Embarked'].replace({'S':1,'C':2,'Q':3})

# %%
df_train.isna().sum()
# Out:
# Survived          0
# Pclass            0
# Sex               0
# Age             177
# SibSp             0
# Parch             0
# Fare              0
# Embarked          2
# Sex_int           0
# Embarked_int      2
# dtype: int64

# %%
df_train = df_train.fillna(0)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
param_grid = { 
    'n_estimators': [25, 50, 100, 150], 
    'max_depth': [3, 6, 9], 
    'max_leaf_nodes': [1,2,3, 6, 9],
    'min_samples_leaf':[0,1,2,3,5,4]
}

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ## Finding Best Hyperparameters

# %%
grid_search = GridSearchCV(RandomForestClassifier(), 
                           param_grid=param_grid) 
grid_search.fit(df_train_features, df_train_target) 
print(grid_search.best_estimator_)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 600 fits failed out of a total of 1800.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 360 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
# ...

# %%
clf = RandomForestClassifier(random_state = 42,max_depth=6, max_leaf_nodes=9, min_samples_leaf=2,n_estimators=150)

# %%
df_train_features = df_train[['Pclass', 'Sex_int', 'Age', 'SibSp','Parch','Fare', 'Embarked_int']]

# %%
df_train_target = df_train['Survived']

# %%
clf.fit(df_train_features, df_train_target)
# Out:
# RandomForestClassifier(max_depth=6, max_leaf_nodes=9, min_samples_leaf=2,
#                        n_estimators=150, random_state=42)

# %%
df_test = pd.read_csv('test.csv')

# %%
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df_test['Sex_int'] = df_test['Sex'].replace({'male':1,'female':0})
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4468\3228916345.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_test['Sex_int'] = df_test['Sex'].replace({'male':1,'female':0})

# %%
df_test['Embarked_int'] = df_test['Embarked'].replace({'S':1,'C':2,'Q':3})
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4468\3703366418.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_test['Embarked_int'] = df_test['Embarked'].replace({'S':1,'C':2,'Q':3})

# %%
df_test = df_test[['PassengerId', 'Pclass','Sex_int','Embarked_int','Fare','Age','SibSp','Parch']]

# %%
d_gender_submission = pd.read_csv('gender_submission.csv')

# %%
d_test_gender_submission = pd.merge(df_test,d_gender_submission, on = 'PassengerId',how= 'left')

# %%
d_test_gender_submission.shape
# Out:
# (418, 9)

# %%
d_test_gender_submission['predict'] = clf.predict(d_test_gender_submission[['Pclass','Sex_int','Age','SibSp','Parch','Fare','Embarked_int']])

# %%
d_test_gender_submission[['predict','Survived']]
# Out:
#      predict  Survived
# 0          0         0
# 1          0         1
# 2          0         0
# 3          0         0
# 4          0         1
# ..       ...       ...
# 413        0         0
# 414        1         1
# 415        0         0
# 416        0         0
# 417        0         0
#
# [418 rows x 2 columns]

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(d_test_gender_submission['Survived'],d_test_gender_submission['predict'])
# Out:
# 0.8851674641148325

# %% [markdown]
# ## LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression

# %%
d_test_gender_submission =d_test_gender_submission.fillna(0)

# %%
logr = LogisticRegression(C=1.2, solver='liblinear')

# %%
logr.fit(df_train_features, df_train_target)
# Out:
# LogisticRegression(C=1.2, solver='liblinear')

# %%
accuracy_score(d_test_gender_submission['Survived'],logr.predict(d_test_gender_submission[['Pclass','Sex_int','Age','SibSp','Parch','Fare','Embarked_int']]))
# Out:
# 0.9712918660287081
